# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import date
import warnings
warnings.filterwarnings('ignore')
import sidetable

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df_miley = pd.read_csv("datos/MileyCyrusSpotifyData.csv")
df_miley.head()
# Out:
#       artist_name               artist_id                album_id album_type  \
# 0  Hannah Montana  7nU4hB040gTmHm45YYMvqc  0TyDqWrWHzuyFjjnKqDClu      album
# 1  Hannah Montana  7nU4hB040gTmHm45YYMvqc  0TyDqWrWHzuyFjjnKqDClu      album
# 2  Hannah Montana  7nU4hB040gTmHm45YYMvqc  0TyDqWrWHzuyFjjnKqDClu      album
# 3  Hannah Montana  7nU4hB040gTmHm45YYMvqc  0TyDqWrWHzuyFjjnKqDClu      album
# 4  Hannah Montana  7nU4hB040gTmHm45YYMvqc  0TyDqWrWHzuyFjjnKqDClu      album
#
#   album_release_date  album_release_year album_release_date_precision  \
# 0         2006-01-01                2006                          day
# 1         2006-01-01                2006                          day
# 2         2006-01-01                2006                          day
# 3         2006-01-01                2006                          day
# 4         2006-01-01                2006                          day
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
df_taylor = pd.read_csv("datos/TaylorSwiftSpotifyData.csv")
df_taylor.head()
# Out:
#     artist_name               artist_id                album_id album_type  \
# 0  Taylor Swift  06HL4z0CvFAxyc27GXpf02  7mzrIsaAjnXihW3InKjlC3      album
# 1  Taylor Swift  06HL4z0CvFAxyc27GXpf02  7mzrIsaAjnXihW3InKjlC3      album
# 2  Taylor Swift  06HL4z0CvFAxyc27GXpf02  7mzrIsaAjnXihW3InKjlC3      album
# 3  Taylor Swift  06HL4z0CvFAxyc27GXpf02  7mzrIsaAjnXihW3InKjlC3      album
# 4  Taylor Swift  06HL4z0CvFAxyc27GXpf02  7mzrIsaAjnXihW3InKjlC3      album
#
#   album_release_date  album_release_year album_release_date_precision  \
# 0         2006-10-24                2006                          day
# 1         2006-10-24                2006                          day
# 2         2006-10-24                2006                          day
# 3         2006-10-24                2006                          day
# 4         2006-10-24                2006                          day
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
df_selena = pd.read_csv("datos/SelenaGomezSpotifyData.csv")
df_selena.head()
# Out:
#                 artist_name               artist_id                album_id  \
# 0  Selena Gomez & The Scene  6dJeKm76NjfXBNTpHmOhfO  5lm8loAsSpprr19lwSY16V
# 1  Selena Gomez & The Scene  6dJeKm76NjfXBNTpHmOhfO  5lm8loAsSpprr19lwSY16V
# 2  Selena Gomez & The Scene  6dJeKm76NjfXBNTpHmOhfO  5lm8loAsSpprr19lwSY16V
# 3  Selena Gomez & The Scene  6dJeKm76NjfXBNTpHmOhfO  5lm8loAsSpprr19lwSY16V
# 4  Selena Gomez & The Scene  6dJeKm76NjfXBNTpHmOhfO  5lm8loAsSpprr19lwSY16V
#
#   album_type album_release_date  album_release_year  \
# 0      album         2009-01-01                2009
# 1      album         2009-01-01                2009
# 2      album         2009-01-01                2009
# 3      album         2009-01-01                2009
# 4      album         2009-01-01                2009
#
#   album_release_date_precision  danceability  energy  key  loudness  mode  \
# 0                          day         0.493   0.923    2    -3.526     1
# ...

# %%
df_shakira = pd.read_csv("datos/ShakiraSpotifyData.csv")
df_shakira.head()
# Out:
#   artist_name               artist_id                album_id album_type  \
# 0     Shakira  0EmeFodog0BfCgMzAIvKQp  3HLngzP9wVd8p3SMDQgyd9      album
# 1     Shakira  0EmeFodog0BfCgMzAIvKQp  3HLngzP9wVd8p3SMDQgyd9      album
# 2     Shakira  0EmeFodog0BfCgMzAIvKQp  3HLngzP9wVd8p3SMDQgyd9      album
# 3     Shakira  0EmeFodog0BfCgMzAIvKQp  3HLngzP9wVd8p3SMDQgyd9      album
# 4     Shakira  0EmeFodog0BfCgMzAIvKQp  3HLngzP9wVd8p3SMDQgyd9      album
#
#   album_release_date  album_release_year album_release_date_precision  \
# 0         1995-10-06                1995                          day
# 1         1995-10-06                1995                          day
# 2         1995-10-06                1995                          day
# 3         1995-10-06                1995                          day
# 4         1995-10-06                1995                          day
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
df_taylor_2020 = df_taylor[df_taylor["album_release_year"] == 2020]

# %%
df_taylor_2020.shape
# Out:
# (225, 36)

# %%
df_charts = pd.read_csv("datos/charts.csv")
# Out:
# Canceled future for execute_request message before replies were done
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.
