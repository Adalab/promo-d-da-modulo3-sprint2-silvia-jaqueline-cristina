# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import date
import warnings
warnings.filterwarnings('ignore')
import sidetable

# %%
df_eurovision = pd.read_csv("datos/eurovision_clean.csv", index_col=0)
df_eurovision.head()
# Out:
#   host_city  year host_country      section            artist       song  \
# 0     Turin  2022        Italy  grand-final         Sam Ryder  SPACE MAN
# 1     Turin  2022        Italy  grand-final            Chanel      SloMo
# 2     Turin  2022        Italy  grand-final  Mahmood & BLANCO    Brividi
# 3     Turin  2022        Italy  grand-final      Alvan & Ahez     Fulenn
# 4     Turin  2022        Italy  grand-final      Malik Harris  Rockstars
#
#    artist_country  running_order  total_points  rank  winner  \
# 0  United Kingdom             22           466     2   False
# 1           Spain             10           459     3   False
# 2           Italy              9           268     6   False
# 3          France              6            17    24   False
# 4         Germany             13             6    25   False
#
#    total_points_per_year  percentage_points  losers
# 0                   4640              10.04    True
# 1                   4640               9.89    True
# ...

# %%
def mayus(x):
    return x.upper()

# %%
df_eurovision["song"] =  df_eurovision["song"].apply(mayus)

# %%
df_eurovision.head()
# Out:
#   host_city  year host_country      section            artist       song  \
# 0     Turin  2022        Italy  grand-final         Sam Ryder  SPACE MAN
# 1     Turin  2022        Italy  grand-final            Chanel      SLOMO
# 2     Turin  2022        Italy  grand-final  Mahmood & BLANCO    BRIVIDI
# 3     Turin  2022        Italy  grand-final      Alvan & Ahez     FULENN
# 4     Turin  2022        Italy  grand-final      Malik Harris  ROCKSTARS
#
#    artist_country  running_order  total_points  rank  winner  \
# 0  United Kingdom             22           466     2   False
# 1           Spain             10           459     3   False
# 2           Italy              9           268     6   False
# 3          France              6            17    24   False
# 4         Germany             13             6    25   False
#
#    total_points_per_year  percentage_points  losers
# 0                   4640              10.04    True
# 1                   4640               9.89    True
# ...

# %%
df_spoti = pd.read_csv("datos/spoti_data.csv", index_col=0)
df_spoti.head()
# Out:
#              song                artists                        album  \
# 0       SPACE MAN          ['Sam Ryder']                    SPACE MAN
# 1  Slomo With You         ['Shady Moon']               Slomo With You
# 2         Brividi  ['Mahmood', 'BLANCO']                      Brividi
# 3          Fulenn      ['Alvan', 'Ahez']                        Magma
# 4       Rockstars         ['Kane Brown']  Kane Brown (Deluxe Edition)
#
#    popularity                                   uri  \
# 0          66  spotify:track:3nhGk6VnrDHy67pXvMhdPa
# 1          53  spotify:track:44HCvFedcxZVN3Op16vUd9
# 2          69  spotify:track:1ZMGp9MTXbtAPvcKa0U3zS
# 3          52  spotify:track:43UejonUIN69O8NNAFRu5X
# 4          40  spotify:track:0BzL36GgqMKCyeW6j6JzzD
#
#                                            image_640  \
# 0  https://i.scdn.co/image/ab67616d0000b273b406a4...
# 1  https://i.scdn.co/image/ab67616d0000b273834d0e...
# 2  https://i.scdn.co/image/ab67616d0000b27340c172...
# ...

# %%
df_spoti["song"] =  df_spoti["song"].apply(mayus)

# %%
df_spoti.head()
# Out:
#              song                artists                        album  \
# 0       SPACE MAN          ['Sam Ryder']                    SPACE MAN
# 1  SLOMO WITH YOU         ['Shady Moon']               Slomo With You
# 2         BRIVIDI  ['Mahmood', 'BLANCO']                      Brividi
# 3          FULENN      ['Alvan', 'Ahez']                        Magma
# 4       ROCKSTARS         ['Kane Brown']  Kane Brown (Deluxe Edition)
#
#    popularity                                   uri  \
# 0          66  spotify:track:3nhGk6VnrDHy67pXvMhdPa
# 1          53  spotify:track:44HCvFedcxZVN3Op16vUd9
# 2          69  spotify:track:1ZMGp9MTXbtAPvcKa0U3zS
# 3          52  spotify:track:43UejonUIN69O8NNAFRu5X
# 4          40  spotify:track:0BzL36GgqMKCyeW6j6JzzD
#
#                                            image_640  \
# 0  https://i.scdn.co/image/ab67616d0000b273b406a4...
# 1  https://i.scdn.co/image/ab67616d0000b273834d0e...
# 2  https://i.scdn.co/image/ab67616d0000b27340c172...
# ...

# %%
df_eurovision.to_csv("datos/eurovision_clean_songs.csv")
df_spoti.to_csv("datos/spoti_songs.csv")
