# %%
import pandas as pd
import numpy as np

# %%
df_eurovision = pd.read_csv("datos/eurovision.csv")
df_eurovision.head()
# Out:
#         event host_city  year host_country  \
# 0  Turin 2022     Turin  2022        Italy
# 1  Turin 2022     Turin  2022        Italy
# 2  Turin 2022     Turin  2022        Italy
# 3  Turin 2022     Turin  2022        Italy
# 4  Turin 2022     Turin  2022        Italy
#
#                                 event_url           section  \
# 0  https://eurovision.tv/event/turin-2022  first-semi-final
# 1  https://eurovision.tv/event/turin-2022  first-semi-final
# 2  https://eurovision.tv/event/turin-2022  first-semi-final
# 3  https://eurovision.tv/event/turin-2022  first-semi-final
# 4  https://eurovision.tv/event/turin-2022  first-semi-final
#
#                       artist              song  \
# 0           Kalush Orchestra          Stefania
# 1                        S10         De Diepte
# 2  Amanda Georgiadi Tenfjord      Die Together
# 3                       MARO  Saudade, Saudade
# 4  Intelligent Music Project         Intention
#
# ...

# %%
df_eurovision.shape
# Out:
# (2005, 18)

# %%
df_eurovision.dtypes
# Out:
# event              object
# host_city          object
# year                int64
# host_country       object
# event_url          object
# section            object
# artist             object
# song               object
# artist_url         object
# image_url          object
# artist_country     object
# country_emoji      object
# running_order     float64
# total_points      float64
# rank              float64
# rank_ordinal       object
# qualified            bool
# winner               bool
# dtype: object

# %%
df_eurovision.isnull().sum()
# Out:
# event                0
# host_city            0
# year                 0
# host_country         0
# event_url            0
# section              0
# artist               0
# song                 1
# artist_url           0
# image_url         1046
# artist_country       0
# country_emoji        0
# running_order        5
# total_points        92
# rank                41
# rank_ordinal        41
# qualified            0
# winner               0
# dtype: int64

# %%
df_eurovision.drop(["artist_url", "event_url", "country_emoji","image_url"], inplace = True, axis = 1)

# %%
df_eurovision.dropna(inplace=True)

# %%
df_eurovision.isnull().sum()
# Out:
# event             0
# host_city         0
# year              0
# host_country      0
# section           0
# artist            0
# song              0
# artist_country    0
# running_order     0
# total_points      0
# rank              0
# rank_ordinal      0
# qualified         0
# winner            0
# dtype: int64

# %%
df_eurovision.shape
# Out:
# (1913, 14)

# %%
df_eurovision["event"].unique()
# Out:
# array(['Turin 2022', 'Rotterdam 2021', 'Tel Aviv 2019', 'Lisbon 2018',
#        'Kyiv 2017', 'Stockholm 2016', 'Vienna 2015', 'Copenhagen 2014',
#        'Malmö 2013', 'Baku 2012', 'Düsseldorf 2011', 'Oslo 2010',
#        'Moscow 2009', 'Belgrade 2008', 'Helsinki 2007', 'Athens 2006',
#        'Kyiv 2005', 'Istanbul 2004', 'Riga 2003', 'Tallinn 2002',
#        'Copenhagen 2001', 'Stockholm 2000', 'Jerusalem 1999',
#        'Birmingham 1998', 'Dublin 1997', 'Oslo 1996', 'Dublin 1995',
#        'Dublin 1994', 'Millstreet 1993', 'Malmö 1992', 'Rome 1991',
#        'Zagreb 1990', 'Lausanne 1989', 'Dublin 1988', 'Brussels 1987',
#        'Bergen 1986', 'Gothenburg 1985', 'Luxembourg 1984', 'Munich 1983',
#        'Harrogate 1982', 'Dublin 1981', 'The Hague 1980',
#        'Jerusalem 1979', 'Paris 1978', 'London 1977', 'The Hague 1976',
#        'Stockholm 1975', 'Brighton 1974', 'Luxembourg 1973',
#        'Edinburgh 1972', 'Dublin 1971', 'Amsterdam 1970', 'Madrid 1969',
# ...

# %%
(df_eurovision.groupby("host_country")["year"].unique()).count()
# Out:
# 26

# %%
df_eurovision.groupby("host_country")["song"].count()
# Out:
# host_country
# Austria            76
# Azerbaijan         62
# Belgium            21
# Denmark            92
# Estonia            24
# Finland            52
# France             46
# Germany            91
# Greece             47
# Ireland           152
# Israel            103
# Italy              95
# Latvia             25
# Luxembourg         64
# Netherlands       117
# Norway            102
# Portugal           63
# Russia             61
# Serbia             63
# Spain              16
# Sweden            206
# Switzerland        21
# Turkey             45
# Ukraine           111
# United Kingdom    136
# Yugoslavia         22
# Name: song, dtype: int64

# %%
df_eurovision.head()
# Out:
#         event host_city  year host_country           section  \
# 0  Turin 2022     Turin  2022        Italy  first-semi-final
# 1  Turin 2022     Turin  2022        Italy  first-semi-final
# 2  Turin 2022     Turin  2022        Italy  first-semi-final
# 3  Turin 2022     Turin  2022        Italy  first-semi-final
# 4  Turin 2022     Turin  2022        Italy  first-semi-final
#
#                       artist              song artist_country  running_order  \
# 0           Kalush Orchestra          Stefania        Ukraine            6.0
# 1                        S10         De Diepte    Netherlands            8.0
# 2  Amanda Georgiadi Tenfjord      Die Together         Greece           15.0
# 3                       MARO  Saudade, Saudade       Portugal           10.0
# 4  Intelligent Music Project         Intention       Bulgaria            7.0
#
#    total_points  rank rank_ordinal  qualified  winner
# 0         337.0   1.0          1st       True   False
# ...

# %%
df_zero = df_eurovision[df_eurovision["total_points"] == 0.0]

# %%
df_bajos = df_eurovision[df_eurovision["total_points"] < 10.0]

# %%
df_bajos[df_bajos["artist_country"] == "Spain"]
# Out:
#                 event   host_city  year    host_country      section  \
# 116    Rotterdam 2021   Rotterdam  2021     Netherlands  grand-final
# 322         Kyiv 2017        Kyiv  2017         Ukraine  grand-final
# 578        Malmö 2013       Malmö  2013          Sweden  grand-final
# 1187   Jerusalem 1999   Jerusalem  1999          Israel        final
# 1788   Amsterdam 1970   Amsterdam  1970     Netherlands        final
# 1841      Vienna 1967      Vienna  1967         Austria        final
# 1854  Luxembourg 1966  Luxembourg  1966      Luxembourg        final
# 1883  Copenhagen 1964  Copenhagen  1964         Denmark        final
# 1903      London 1963      London  1963  United Kingdom        final
# 1946      Cannes 1961      Cannes  1961          France        final
#
#                    artist                                             song  \
# 116            Blas Cantó                                   Voy A Quedarme
# ...

# %%
df_eurovision["section"].unique()
# Out:
# array(['first-semi-final', 'second-semi-final', 'grand-final',
#        'semi-final', 'final'], dtype=object)

# %%
df_eurovision_finales = df_eurovision[(df_eurovision["section"] == "grand-final") | (df_eurovision["section"] == "final")]

# %%
df_eurovision_finales["section"].unique()
# Out:
# array(['grand-final', 'final'], dtype=object)

# %%
df_eurovision_finales.head()
# Out:
#          event host_city  year host_country      section            artist  \
# 35  Turin 2022     Turin  2022        Italy  grand-final         Sam Ryder
# 36  Turin 2022     Turin  2022        Italy  grand-final            Chanel
# 37  Turin 2022     Turin  2022        Italy  grand-final  Mahmood & BLANCO
# 38  Turin 2022     Turin  2022        Italy  grand-final      Alvan & Ahez
# 39  Turin 2022     Turin  2022        Italy  grand-final      Malik Harris
#
#          song  artist_country  running_order  total_points  rank rank_ordinal  \
# 35  SPACE MAN  United Kingdom           22.0         466.0   2.0          2nd
# 36      SloMo           Spain           10.0         459.0   3.0          3rd
# 37    Brividi           Italy            9.0         268.0   6.0          6th
# 38     Fulenn          France            6.0          17.0  24.0         24th
# 39  Rockstars         Germany           13.0           6.0  25.0         25th
#
#     qualified  winner
# 35      False   False
# ...

# %%
df_eurovision_finales.shape
# Out:
# (1325, 14)

# %%
df_eurovision_finales[["event", "host_city", "year"]].sample(15)
# Out:
#                 event   host_city  year
# 1027        Kyiv 2005        Kyiv  2005
# 575        Malmö 2013       Malmö  2013
# 1776      Dublin 1971      Dublin  1971
# 1816      London 1968      London  1968
# 1345  Millstreet 1993  Millstreet  1993
# 869     Belgrade 2008    Belgrade  2008
# 102    Rotterdam 2021   Rotterdam  2021
# 822       Moscow 2009      Moscow  2009
# 924     Helsinki 2007    Helsinki  2007
# 808       Moscow 2009      Moscow  2009
# 1802      Madrid 1969      Madrid  1969
# 1591      Dublin 1981      Dublin  1981
# 821       Moscow 2009      Moscow  2009
# 1299      Dublin 1995      Dublin  1995
# 827       Moscow 2009      Moscow  2009

# %%
df_eurovision_finales.drop("event", axis = 1, inplace = True)
# Out:
# /tmp/ipykernel_352/2064548969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales.drop("event", axis = 1, inplace = True)

# %%
df_eurovision_finales.head()
# Out:
#    host_city  year host_country      section            artist       song  \
# 35     Turin  2022        Italy  grand-final         Sam Ryder  SPACE MAN
# 36     Turin  2022        Italy  grand-final            Chanel      SloMo
# 37     Turin  2022        Italy  grand-final  Mahmood & BLANCO    Brividi
# 38     Turin  2022        Italy  grand-final      Alvan & Ahez     Fulenn
# 39     Turin  2022        Italy  grand-final      Malik Harris  Rockstars
#
#     artist_country  running_order  total_points  rank rank_ordinal  qualified  \
# 35  United Kingdom           22.0         466.0   2.0          2nd      False
# 36           Spain           10.0         459.0   3.0          3rd      False
# 37           Italy            9.0         268.0   6.0          6th      False
# 38          France            6.0          17.0  24.0         24th      False
# 39         Germany           13.0           6.0  25.0         25th      False
#
#     winner
# 35   False
# 36   False
# 37   False
# ...

# %%
df_eurovision_finales["qualified"].unique()
# Out:
# array([False])

# %%
df_eurovision_finales.drop("qualified", axis = 1, inplace = True)
# Out:
# /tmp/ipykernel_352/3747518940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales.drop("qualified", axis = 1, inplace = True)

# %%
df_eurovision_finales.reset_index(inplace= True, drop=True)

# %%
df_eurovision_finales.head()
# Out:
#   host_city  year host_country      section            artist       song  \
# 0     Turin  2022        Italy  grand-final         Sam Ryder  SPACE MAN
# 1     Turin  2022        Italy  grand-final            Chanel      SloMo
# 2     Turin  2022        Italy  grand-final  Mahmood & BLANCO    Brividi
# 3     Turin  2022        Italy  grand-final      Alvan & Ahez     Fulenn
# 4     Turin  2022        Italy  grand-final      Malik Harris  Rockstars
#
#    artist_country  running_order  total_points  rank rank_ordinal  winner
# 0  United Kingdom           22.0         466.0   2.0          2nd   False
# 1           Spain           10.0         459.0   3.0          3rd   False
# 2           Italy            9.0         268.0   6.0          6th   False
# 3          France            6.0          17.0  24.0         24th   False
# 4         Germany           13.0           6.0  25.0         25th   False

# %%
df_eurovision_finales["rank"].unique()
# Out:
# array([ 2.,  3.,  6., 24., 25.,  1., 11., 12., 13., 14., 15., 16., 17.,
#        18., 19.,  4.,  5.,  7.,  8.,  9., 10., 20., 21., 22., 23., 26.,
#        27.])

# %%
df_eurovision_finales["rank"] = df_eurovision_finales["rank"].astype("int64")
# Out:
# /tmp/ipykernel_352/3513139148.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales["rank"] = df_eurovision_finales["rank"].astype("int64")

# %%
df_eurovision_finales.dtypes
# Out:
# host_city          object
# year                int64
# host_country       object
# section            object
# artist             object
# song               object
# artist_country     object
# running_order     float64
# total_points      float64
# rank                int64
# rank_ordinal       object
# winner               bool
# dtype: object

# %%
df_eurovision_finales["total_points"] = df_eurovision_finales["total_points"].astype("int64")
# Out:
# /tmp/ipykernel_352/123888096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales["total_points"] = df_eurovision_finales["total_points"].astype("int64")

# %%
df_eurovision_finales["running_order"] = df_eurovision_finales["running_order"].astype("int64")
# Out:
# /tmp/ipykernel_352/344829491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales["running_order"] = df_eurovision_finales["running_order"].astype("int64")

# %%
df_eurovision_finales.dtypes
# Out:
# host_city         object
# year               int64
# host_country      object
# section           object
# artist            object
# song              object
# artist_country    object
# running_order      int64
# total_points       int64
# rank               int64
# rank_ordinal      object
# winner              bool
# dtype: object

# %%
df_eurovision_finales.drop("rank_ordinal", axis = 1, inplace = True)
# Out:
# /tmp/ipykernel_352/1935110481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales.drop("rank_ordinal", axis = 1, inplace = True)

# %%
df_eurovision_finales
# Out:
#       host_city  year host_country      section              artist  \
# 0         Turin  2022        Italy  grand-final           Sam Ryder
# 1         Turin  2022        Italy  grand-final              Chanel
# 2         Turin  2022        Italy  grand-final    Mahmood & BLANCO
# 3         Turin  2022        Italy  grand-final        Alvan & Ahez
# 4         Turin  2022        Italy  grand-final        Malik Harris
# ...         ...   ...          ...          ...                 ...
# 1320  Frankfurt  1957      Germany        final          Bob Martin
# 1321  Frankfurt  1957      Germany        final        Nunzio Gallo
# 1322  Frankfurt  1957      Germany        final     Patricia Bredin
# 1323  Frankfurt  1957      Germany        final       Danièle Dupré
# 1324  Frankfurt  1957      Germany        final  Bobbejaan Schoepen
#
#                           song  artist_country  running_order  total_points  \
# ...

# %%
df_eurovision_finales.groupby("year")["total_points"].sum()
# Out:
# year
# 1957     100
# 1958     100
# 1959     110
# 1960     130
# 1961     160
#         ...
# 2017    4872
# 2018    4988
# 2019    4756
# 2021    4524
# 2022    4640
# Name: total_points, Length: 65, dtype: int64

# %%
df_eurovision_finales["total_points_per_year"] = df_eurovision_finales.groupby("year")["total_points"].transform("sum")
# Out:
# /tmp/ipykernel_352/159264032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales["total_points_per_year"] = df_eurovision_finales.groupby("year")["total_points"].transform("sum")

# %%
df_eurovision_finales.tail()
# Out:
#       host_city  year host_country section              artist  \
# 1320  Frankfurt  1957      Germany   final          Bob Martin
# 1321  Frankfurt  1957      Germany   final        Nunzio Gallo
# 1322  Frankfurt  1957      Germany   final     Patricia Bredin
# 1323  Frankfurt  1957      Germany   final       Danièle Dupré
# 1324  Frankfurt  1957      Germany   final  Bobbejaan Schoepen
#
#                           song  artist_country  running_order  total_points  \
# 1320       Wohin, Kleines Pony         Austria              5             3
# 1321  Corde Della Mia Chitarra           Italy              4             7
# 1322                       All  United Kingdom              3             6
# 1323             Tant De Peine      Luxembourg              2             8
# 1324             Straatdeuntje         Belgium              1             5
#
#       rank  winner  total_points_per_year
# 1320    10   False                    100
# 1321     6   False                    100
# ...

# %%
df_eurovision_finales["percentage_points"] = round((df_eurovision_finales["total_points"]/df_eurovision_finales["total_points_per_year"])*100, 2)
# Out:
# /tmp/ipykernel_352/498443695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales["percentage_points"] = round((df_eurovision_finales["total_points"]/df_eurovision_finales["total_points_per_year"])*100, 2)

# %%
df_eurovision_losers = df_eurovision_finales.groupby("year")["rank"].max().reset_index()

# %%
df_eurovision_losers
# Out:
#     year  rank
# 0   1957    10
# 1   1958     9
# 2   1959    11
# 3   1960    13
# 4   1961    15
# ..   ...   ...
# 60  2017    26
# 61  2018    26
# 62  2019    26
# 63  2021    26
# 64  2022    25
#
# [65 rows x 2 columns]

# %%
for year in df_eurovision_finales["year"]:
    if year in(df_eurovision_losers["year"]):
        if df_eurovision_losers["rank"] == df_eurovision_finales["rank"]:
            df_eurovision_finales["losers"] = True
        else:
            df_eurovision_finales["losers"] = False

# %%
df_eurovision_finales.head()
# Out:
#   host_city  year host_country      section            artist       song  \
# 0     Turin  2022        Italy  grand-final         Sam Ryder  SPACE MAN
# 1     Turin  2022        Italy  grand-final            Chanel      SloMo
# 2     Turin  2022        Italy  grand-final  Mahmood & BLANCO    Brividi
# 3     Turin  2022        Italy  grand-final      Alvan & Ahez     Fulenn
# 4     Turin  2022        Italy  grand-final      Malik Harris  Rockstars
#
#    artist_country  running_order  total_points  rank  winner  \
# 0  United Kingdom             22           466     2   False
# 1           Spain             10           459     3   False
# 2           Italy              9           268     6   False
# 3          France              6            17    24   False
# 4         Germany             13             6    25   False
#
#    total_points_per_year  percentage_points
# 0                   4640              10.04
# 1                   4640               9.89
# ...

# %%
df_eurovision_finales["winner"].value_counts()
# Out:
# False    1257
# True       68
# Name: winner, dtype: int64

# %%
def cambiar_columna (col): 
    if col == True:
        return False
    else:
        return True

# %%
df_eurovision_finales["losers"] = df_eurovision_finales["winner"].apply(cambiar_columna)
# Out:
# /tmp/ipykernel_352/1555551924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eurovision_finales["losers"] = df_eurovision_finales["winner"].apply(cambiar_columna)

# %%
df_eurovision_finales.head()
# Out:
#   host_city  year host_country      section            artist       song  \
# 0     Turin  2022        Italy  grand-final         Sam Ryder  SPACE MAN
# 1     Turin  2022        Italy  grand-final            Chanel      SloMo
# 2     Turin  2022        Italy  grand-final  Mahmood & BLANCO    Brividi
# 3     Turin  2022        Italy  grand-final      Alvan & Ahez     Fulenn
# 4     Turin  2022        Italy  grand-final      Malik Harris  Rockstars
#
#    artist_country  running_order  total_points  rank  winner  \
# 0  United Kingdom             22           466     2   False
# 1           Spain             10           459     3   False
# 2           Italy              9           268     6   False
# 3          France              6            17    24   False
# 4         Germany             13             6    25   False
#
#    total_points_per_year  percentage_points  losers
# 0                   4640              10.04    True
# 1                   4640               9.89    True
# ...

# %%
df_eurovision_finales["losers"].unique()
# Out:
# array([ True, False])

# %%
df_eurovision_finales["losers"].value_counts()
# Out:
# True     1257
# False      68
# Name: losers, dtype: int64

# %%
(df_eurovision_finales[df_eurovision_finales["rank"] == 1]).sort_values(by="year").head(50)
# Out:
#        host_city  year    host_country section  \
# 1319   Frankfurt  1957         Germany   final
# 1309   Hilversum  1958     Netherlands   final
# 1300      Cannes  1959          France   final
# 1281      London  1960  United Kingdom   final
# 1267      Cannes  1961          France   final
# 1260  Luxembourg  1962      Luxembourg   final
# 1248      London  1963  United Kingdom   final
# 1231  Copenhagen  1964         Denmark   final
# 1217      Naples  1965           Italy   final
# 1206  Luxembourg  1966      Luxembourg   final
# 1192      Vienna  1967         Austria   final
# 1168      London  1968  United Kingdom   final
# 1163      Madrid  1969           Spain   final
# 1159      Madrid  1969           Spain   final
# 1158      Madrid  1969           Spain   final
# 1152      Madrid  1969           Spain   final
# 1139   Amsterdam  1970     Netherlands   final
# 1136      Dublin  1971         Ireland   final
# 1104   Edinburgh  1972  United Kingdom   final
# ...

# %%
df_eurovision_finales[df_eurovision_finales["rank"] == 1].groupby("year")

# %%
# for index, year in enumerate (df_eurovision_finales["year"]):
#     if year == df_eurovision_losers["year"][index]:
#         for index, ranking in enumerate (df_eurovision_finales["rank"]):
#                 if ranking == df_eurovision_losers["rank"]:
#                     df_eurovision_finales["losers"] = True
#                 else:
#                     df_eurovision_finales["losers"] = False

# %%
#df1 será df_eurovision_finales y df2 será df_eurovision_losers
# def crear_columna (col1, col2):
#     for year in col1:
#         if col2 == col2:
#             if df1["rank"] == df2["rank"]:
#                 return True
#             else:
#                 return False

# %%
# df_eurovision_finales["losers"] = df_eurovision_finales.apply(lambda data: crear_columna(df_eurovision_finales, df_eurovision_losers), axis = 1)

# %%
df_eurovision_finales.to_csv("datos/eurovision_clean.csv")
